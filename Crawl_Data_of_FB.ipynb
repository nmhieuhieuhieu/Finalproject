# %% [markdown]
# <a href="https://colab.research.google.com/github/nmhieuhieuhieu/Finalproject/blob/main/Crawl_Data_of_FB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %pip install facebook_scraper

# %%
# Import thư viện cần thiết
from facebook_scraper import get_posts
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
FANPAGE_LINK ="Divodivafanvietnam"
FOLDER_PATH = "/content/drive/MyDrive/Tumblr Vietnam/"
COOKIE_PATH = "/content/drive/MyDrive/Tumblr Vietnam/cookies .txt"

# %%
from facebook_scraper import get_posts
import pandas as pd

# %%
post_list = []
for post in get_posts(FANPAGE_LINK,
                    options={"comments": True, "reactions": True, "allow_extra_requests": True},
                    extra_info=True, pages=10, cookies=COOKIE_PATH):
    post_list.append(post)
# Out:
# WARNING:facebook_scraper.extractors:[731184905717847] Extract method extract_video_meta didn't return anything
# WARNING:facebook_scraper.extractors:[731184905717847] Extract method extract_factcheck didn't return anything
# WARNING:facebook_scraper.extractors:[731184905717847] Extract method extract_share_information didn't return anything
# WARNING:facebook_scraper.extractors:[731184905717847] Extract method extract_listing didn't return anything
# WARNING:facebook_scraper.extractors:[731184905717847] Extract method extract_with didn't return anything
# ERROR:facebook_scraper.extractors:Unable to parse comment <Element 'div' class=('_2a_i',) data-store='{"token":"731184905717847_301365949328686"}' id='301365949328686' data-uniqueid='301365949328686' data-gt='{"tn":"R"}' data-sigil='comment'>: invalid literal for int() with base 10: 'Tất cả 8'
# ...

# %%
len(post_list)
# Out:
# 100

# %%
post_df_full = pd.DataFrame(columns = [])
for post in post_list:
    post_entry = post
    fb_post_df = pd.DataFrame.from_dict(post_entry, orient='index')
    fb_post_df = fb_post_df.transpose()
    post_df_full = post_df_full.append(fb_post_df)
# Out:
# <ipython-input-94-dc3d204f51ed>:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   post_df_full = post_df_full.append(fb_post_df)
# <ipython-input-94-dc3d204f51ed>:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   post_df_full = post_df_full.append(fb_post_df)
# <ipython-input-94-dc3d204f51ed>:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   post_df_full = post_df_full.append(fb_post_df)
# <ipython-input-94-dc3d204f51ed>:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   post_df_full = post_df_full.append(fb_post_df)
# ...

# %%
path=FOLDER_PATH + FANPAGE_LINK + ".xlsx"
post_df_full.to_excel(FOLDER_PATH + FANPAGE_LINK + ".xlsx", index=False)
print(path)
# Out:
# /content/drive/MyDrive/Tumblr Vietnam/Divodivafanvietnam.xlsx

# %%
import numpy as np
arr = np.array(post_list)
path1=FOLDER_PATH + FANPAGE_LINK + ".npy"
np.save(path1, arr)
print(path1)
# Out:
# /content/drive/MyDrive/Tumblr Vietnam/Divodivafanvietnam.npy
